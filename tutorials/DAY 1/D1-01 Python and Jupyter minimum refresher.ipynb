# %% [markdown]
# # D1-01 Python and Jupyter minimum refresher
#
# Audience: participants with limited Python experience.

# %% [markdown]
# ## Learning goals
#
# - Understand variables, lists, dictionaries, loops, and functions.
# - Use notebooks safely (run order, restart kernel, rerun all).

# %%
numbers = [2, 4, 6, 8]
scaled = [x * 1.5 for x in numbers]
print('Scaled values:', scaled)

# %%
activity = {
    'name': 'electricity, medium voltage',
    'unit': 'kWh',
    'location': 'ES'
}

for key, value in activity.items():
    print(key, '->', value)

# %%
def impact_per_unit(inventory_amount, cf):
    return inventory_amount * cf

print('Impact:', impact_per_unit(3.2, 0.45))

# %% [markdown]
# ## Exercise
#
# Write a function `total_impact(flows, cfs)` where:
# - `flows` is a dictionary such as `{'co2': 4.0, 'ch4': 0.1}`
# - `cfs` is a dictionary with matching factors.
#
# Return the weighted sum.

# %%
# TODO

# %%
def total_impact(flows, cfs):
    return sum(amount * cfs.get(flow, 0) for flow, amount in flows.items())

flows = {'co2': 4.0, 'ch4': 0.1}
cfs = {'co2': 1.0, 'ch4': 27.0}
print(total_impact(flows, cfs))
