# %% [markdown]
# # D3-01 Day 2 recap and scenario framing
#
# Run this notebook in the `bw` environment unless noted otherwise.

# %% [markdown]
# ## Learning goals
#
# - Consolidate key Day 2 concepts.
# - Frame scenario assumptions for Day 3 work.

# %% [markdown]
# ## Concept
#
# A clear scenario frame prevents inconsistent assumptions in scenario-based LCIA.

# %%
assumptions = {
    'time_horizon': '2030-2050',
    'region_scope': 'Europe',
    'baseline': 'Current policy',
}
assumptions

# %% [markdown]
# ## Exercise
#
# Add one uncertainty source for each assumption (time, region, baseline).

# %%
# TODO

# %%
uncertainties = {
    'time_horizon': 'technology learning rates',
    'region_scope': 'intra-regional heterogeneity',
    'baseline': 'policy implementation gap',
}
uncertainties
