# %% [markdown]
# # D3-06 Capstone dual case study
#
# Run this notebook in the `bw2` environment unless noted otherwise.

# %% [markdown]
# ## Learning goals
#
# - Run a compact scenario-based LCIA case.
# - Run a compact inventory-flow criticality case.
# - Compare methodological strengths and limitations.

# %% [markdown]
# ## Concept
#
# Capstone combines Day 2 and Day 3 methods into a final applied exercise.

# %%
import pandas as pd

capstone_template = {
    'task_1_scenario_lcia': 'Fill in model choices, assumptions, and results.',
    'task_2_inventory_flow': 'Fill in tracked materials, factors, and vulnerability results.',
    'reflection': 'List top 3 limitations and next improvements.'
}
capstone_template

# %% [markdown]
# ## Exercise
#
# Complete the template with your team outputs and prepare a 5-minute report.

# %%
# TODO

# %%
completed = pd.DataFrame([
    {'section': 'task_1_scenario_lcia', 'status': 'done'},
    {'section': 'task_2_inventory_flow', 'status': 'done'},
    {'section': 'reflection', 'status': 'draft'},
])
completed
