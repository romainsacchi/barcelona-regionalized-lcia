# %% [markdown]
# # D2-02 Edges fundamentals and regionalisation concepts
#
# Run this notebook in the `bw` environment unless noted otherwise.

# %% [markdown]
# ## Learning goals
#
# - Understand what Edges adds to Brightway.
# - Differentiate global and regionalized characterization.

# %% [markdown]
# ## Concept
#
# Edges extends impact assessment by enabling flexible and location-aware characterization workflows.

# %%
import edges
print('Edges version:', getattr(edges, '__version__', 'unknown'))

# Explore the package namespace
print('Some Edges attributes:', [name for name in dir(edges) if not name.startswith('_')][:20])

# %% [markdown]
# ## Exercise
#
# Write a short note describing when regionalized CFs are critical for decision-making.

# %%
# TODO

# %%
note = '''Regionalized CFs matter when the same emission/resource use has very different impacts
across locations (e.g., water scarcity, biodiversity sensitivity).'''
print(note)
