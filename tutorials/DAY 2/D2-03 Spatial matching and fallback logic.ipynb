# %% [markdown]
# # D2-03 Spatial matching and fallback logic
#
# Run this notebook in the `bw2` environment unless noted otherwise.

# %% [markdown]
# ## Learning goals
#
# - Understand spatial matching from inventory locations to CF regions.
# - Explain fallback order when direct matches are missing.

# %% [markdown]
# ## Concept
#
# Regionalized LCIA requires transparent rules to map process locations to characterization geographies.

# %%
import pandas as pd

mapping = pd.DataFrame([
    {'inventory_location': 'ES', 'matched_cf_region': 'ES', 'fallback_level': 'exact'},
    {'inventory_location': 'PT', 'matched_cf_region': 'RER', 'fallback_level': 'regional'},
    {'inventory_location': 'GLO', 'matched_cf_region': 'GLO', 'fallback_level': 'global'},
])
mapping

# %% [markdown]
# ## Exercise
#
# Add one row where an unknown location falls back to `GLO` and explain why.

# %%
# TODO

# %%
mapping.loc[len(mapping)] = {
    'inventory_location': 'XX',
    'matched_cf_region': 'GLO',
    'fallback_level': 'global fallback'
}
mapping
