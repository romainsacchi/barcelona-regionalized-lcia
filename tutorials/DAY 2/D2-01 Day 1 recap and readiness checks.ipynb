# %% [markdown]
# # D2-01 Day 1 recap and readiness checks
#
# Run this notebook in the `bw2` environment unless noted otherwise.

# %% [markdown]
# ## Learning goals
#
# - Recall Day 1 core concepts before regionalized LCIA.
# - Validate package imports and project readiness.

# %% [markdown]
# ## Concept
#
# Use this notebook as a warm-up and debugging checkpoint before Edges sessions.

# %%
import importlib

for pkg in ['bw2data', 'bw2calc', 'edges']:
    spec = importlib.util.find_spec(pkg)
    print(pkg, 'OK' if spec else 'MISSING')

# %% [markdown]
# ## Exercise
#
# List three differences between deterministic LCA and Monte Carlo LCA in your own words.

# %%
# TODO

# %%
answers = {
    'difference_1': 'Deterministic gives one score, Monte Carlo gives a distribution.',
    'difference_2': 'Monte Carlo samples uncertain parameters repeatedly.',
    'difference_3': 'Uncertainty analysis reports spread and confidence, not only a mean.'
}
answers
