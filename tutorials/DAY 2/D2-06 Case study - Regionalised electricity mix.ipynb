# %% [markdown]
# # D2-06 Case study - Regionalised electricity mix
#
# Run this notebook in the `bw2` environment unless noted otherwise.

# %% [markdown]
# ## Learning goals
#
# - Apply the full Day 2 workflow to an electricity case study.
# - Interpret regionalized results and limitations.

# %% [markdown]
# ## Concept
#
# Use provided assets in `tutorials/DAY 2/assets/` as case-study input data.

# %%
from pathlib import Path
import pandas as pd

assets = Path('tutorials/DAY 2/assets') if Path('tutorials/DAY 2/assets').exists() else Path('assets')
files = sorted([p.name for p in assets.glob('*')])
print('Available case-study files:')
for f in files:
    print('-', f)

# Template for student results table
results = pd.DataFrame(columns=['mix_name', 'indicator', 'score'])
results

# %% [markdown]
# ## Exercise
#
# Populate `results` with at least two electricity mixes and two indicators.

# %%
# TODO

# %%
results = pd.DataFrame([
    {'mix_name': 'Mix A', 'indicator': 'freshwater use', 'score': 23.1},
    {'mix_name': 'Mix A', 'indicator': 'biodiversity', 'score': 4.8},
    {'mix_name': 'Mix B', 'indicator': 'freshwater use', 'score': 17.4},
    {'mix_name': 'Mix B', 'indicator': 'biodiversity', 'score': 6.2},
])
results
