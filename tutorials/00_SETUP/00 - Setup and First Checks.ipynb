# %% [markdown]
# # 00 - Setup and First Checks
#
# This notebook helps participants prepare their machine before Day 1.
# Use it with `INSTRUCTIONS.MD`.
#
# Run this notebook in any working Python environment.

# %% [markdown]
# ## Learning goals
#
# - Confirm Git and Conda are installed.
# - Understand basic terminal navigation.
# - Create and activate the course environment.
# - Verify that the BAFU:2025 Excel inventory file is in the expected folder.

# %%
import os
import sys
import platform

print('Python:', sys.version.split()[0])
print('Executable:', sys.executable)
print('Platform:', platform.platform())
print('Current folder:', os.getcwd())

# %% [markdown]
# ## Terminal basics
#
# Try these commands in your terminal:
#
# ```bash
# pwd
# ls
# cd ..
# cd <folder_name>
# mkdir rlcia-course
# ```

# %% [markdown]
# ## Git and Conda checks
#
# Run in a terminal:
#
# ```bash
# git --version
# conda --version
# conda env list
# ```
#
# If a command is not found, follow `INSTRUCTIONS.MD`.

# %%
import shutil

for tool in ['git', 'conda', 'jupyter']:
    print(f"{tool}:", shutil.which(tool) or 'NOT FOUND on PATH')

# %% [markdown]
# ## Create the course environment
#
# From the repository root:
#
# ```bash
# cd envs
# ```
#
# Choose one command:
#
# ```bash
# conda env create -f bw2_env_osxARM.yaml   # Mac Apple Silicon
# conda env create -f bw2_env_win64.yaml    # Windows or Mac Intel
# ```
#
# Then activate:
#
# ```bash
# conda activate bw2
# ```

# %% [markdown]
# ## Check BAFU:2025 file location
#
# Place the Brightway-compatible BAFU Excel file in:
#
# - `tutorials/DAY 1/assets/BAFU_2025_inventory.xlsx`
#
# You will import this file on Day 1.

# %%
from pathlib import Path

bafu_path = Path('tutorials/DAY 1/assets/BAFU_2025_inventory.xlsx')
print('BAFU file expected at:', bafu_path.resolve())
print('Found:', bafu_path.exists())

# %% [markdown]
# ## Terms of use reminder (BAFU:2025)
#
# - Data may not be resold.
# - Cite source as: `Database of the Swiss Federal Administration, FOEN:20XY, Federal Office for the Environment, 2025.`
# - Swiss Federal Administration cannot be held responsible for the published data.

# %% [markdown]
# ## Launch Jupyter
#
# ```bash
# jupyter lab
# ```
#
# Open this repository and run cells from top to bottom.

# %% [markdown]
# ## Exercise
#
# Create a new text file named `setup_check.txt` in the repository root from your terminal.
# Then confirm from Python that the file exists.

# %%
# TODO: write your check here
# hint: use os.path.exists('setup_check.txt')

# %%
import os
print('setup_check.txt exists:', os.path.exists('setup_check.txt'))

# %% [markdown]
# ## Troubleshooting quick list
#
# - `conda: command not found`: restart terminal, then re-check PATH.
# - Kernel mismatch: in Jupyter, switch kernel to the environment used for the session.
# - Import error: run `conda list` and verify the package is installed in the active env.
